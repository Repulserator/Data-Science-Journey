# %%
import json
import pandas as pd

# %%
# jsonfile = open('nested_data.json','r')
# jsondata = jsonfile.read()
# obj = json.loads(jsondata)

with open("nested_data.json") as f:
    data = json.load(f)


len(data['programs'][13953])
# Out:
# 6

# %%
dff = pd.json_normalize(data['programs'])

# %%
dff
# Out:
#         season                                 orchestra  \
# 0      1842-43                     New York Philharmonic
# 1      1842-43                     New York Philharmonic
# 2      1842-43  Musicians from the New York Philharmonic
# 3      1842-43                     New York Philharmonic
# 4      1843-44                     New York Philharmonic
# ...        ...                                       ...
# 13949  2016-17  Musicians from the New York Philharmonic
# 13950  2016-17                     New York Philharmonic
# 13951  2016-17                     New York Philharmonic
# 13952  2016-17                     New York Philharmonic
# 13953  2016-17                     New York Philharmonic
#
#                                                 concerts programID  \
# 0      [{'Date': '1842-12-07T05:00:00Z', 'eventType':...      3853
# 1      [{'Date': '1843-02-18T05:00:00Z', 'eventType':...      5178
# 2      [{'Date': '1843-04-07T05:00:00Z', 'eventType':...     10785
# ...

# %%
dff.head(20).sort_values('programID')
# Out:
#      season                                 orchestra  \
# 2   1842-43  Musicians from the New York Philharmonic
# 14  1845-46                     New York Philharmonic
# 15  1845-46                     New York Philharmonic
# 9   1844-45                     New York Philharmonic
# 16  1845-46                     New York Philharmonic
# 10  1844-45                     New York Philharmonic
# 4   1843-44                     New York Philharmonic
# 11  1844-45                     New York Philharmonic
# 5   1843-44                     New York Philharmonic
# 17  1846-47                     New York Philharmonic
# 0   1842-43                     New York Philharmonic
# 6   1843-44                     New York Philharmonic
# 19  1846-47                     New York Philharmonic
# 12  1845-46                     New York Philharmonic
# 7   1843-44                     New York Philharmonic
# 1   1842-43                     New York Philharmonic
# ...

# %%
dffworks = pd.json_normalize(data = data['programs'], record_path='works',meta = ['season','orchestra','programID'])

# %%
dffworks.head(10)
# Out:
#                                          workTitle        conductorName  \
# 0                 SYMPHONY NO. 5 IN C MINOR, OP.67  Hill, Ureli Corelli
# 1                                           OBERON       Timm, Henry C.
# 2                  QUINTET, PIANO, D MINOR, OP. 74                  NaN
# 3                                              NaN                  NaN
# 4                                           OBERON    Etienne, Denis G.
# 5                                           ARMIDA       Timm, Henry C.
# 6                                  FIDELIO, OP. 72       Timm, Henry C.
# 7           ABDUCTION FROM THE SERAGLIO,THE, K.384       Timm, Henry C.
# 8                  OVERTURE NO. 1, D MINOR, OP. 38       Timm, Henry C.
# 9  SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)  Hill, Ureli Corelli
#
#        ID                                           soloists  \
# 0  52446*                                                 []
# ...

# %%
dffworkssoloists = pd.json_normalize(data = data['programs'], record_path=['works','soloists'],meta = ['season','orchestra','programID'])
dffworkssoloists
# Out:
#                                              soloistName soloistRoles  \
# 0                                       Otto, Antoinette            S
# 1                                  Scharfenberg, William            A
# 2                                    Hill, Ureli Corelli            A
# 3                                         Derwort, G. H.            A
# 4                                        Boucher, Alfred            A
# ...                                                  ...          ...
# 56189                                         Xu, Weiqin            S
# 56190                                Martin, Christopher            S
# 56191                                     Shryock, Grace            S
# 56192  Jazz at Lincoln Center Orchestra with Wynton M...            S
# 56193  Jazz at Lincoln Center Orchestra with Wynton M...            S
#
#       soloistInstrument   season              orchestra programID
# ...

# %%
dff.works.concerts = pd.json_normalize(data = data['programs'], record_path=['concerts'],meta = ['season','orchestra','programID'])
dff.works.concerts.sort_values('programID').head(10)
# Out:
#                        Date            eventType  \
# 622    1897-02-06T05:00:00Z  Subscription Season
# 621    1897-02-05T05:00:00Z  Subscription Season
# 9648   1957-12-01T05:00:00Z  Subscription Season
# 6482   1940-02-29T05:00:00Z  Subscription Season
# 6483   1940-03-01T05:00:00Z  Subscription Season
# 5430   1934-02-23T05:00:00Z  Subscription Season
# 5429   1934-02-22T05:00:00Z  Subscription Season
# 16601  1993-06-26T04:00:00Z                Parks
# 19731  2009-03-09T04:00:00Z                 Tour
# 19780  2009-05-25T04:00:00Z  St. John the Divine
#
#                                                Venue       Location    Time  \
# 622                                    Carnegie Hall  Manhattan, NY  8:15PM
# 621                                    Carnegie Hall  Manhattan, NY  2:00PM
# 9648                                   Carnegie Hall  Manhattan, NY  3:00PM
# 6482                                   Carnegie Hall  Manhattan, NY  8:45PM
# ...
